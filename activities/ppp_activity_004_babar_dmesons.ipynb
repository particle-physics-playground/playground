# %% [markdown]
# # Reconstructing $D^0$ mesons

# %% [markdown]
# <h3>Learning goals</h3>
# <ul>
#     <li>Relativistic kinematics.
#     <li>Mesons.
# </ul>

# %% [markdown]
# To prepare for this activity, you should already have looked at the activity on <a href="https://github.com/particle-physics-playground/playground/blob/master/activities/ACTIVITY_dimuon_spectrum.ipynb">how to reconstruct particles from their decay products</a> and <a href="https://github.com/particle-physics-playground/playground/blob/master/activities/hello_CLEO.ipynb">how to interface with CLEO data</a>.
#
# After you are familiar with those activities, use the <a href="https://github.com/particle-physics-playground/playground/blob/master/activities/download_more_data.ipynb">download-more-data notebook</a> and grab the Monte Carlo file that simulates the following decay:
#
# $$D^0 \rightarrow K^- \pi^+ $$
# Also grab the PID_R24-AllEvents data file.
#
#
# The challenge:
# Sometimes the peaks of a particle can be quite small in comparison to the background. Sometimes you can eliminate the background, other times you must be able to recognize a significant anomaly in the data when you see it. You dont always have to change the data itself, sometimes modifying the way it is displayed can show you something you couldn't see before.
# * You can try a different range over which the data is displayed.
# * You can try changing the bin size of the histogram.
# * Even relatively small peaks in the graph have a chance to be significant.

# %%
from IPython.display import Image
Image(filename='images/discovering_sketch_D.jpg')
